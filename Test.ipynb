# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 from Data_preparation.Data_cleaning import final_game_situation_data
#
# ModuleNotFoundError: No module named 'Data_preparation.Data_cleaning'

# %%
from Data_preparation.Data_cleaning import final_game_situation_data
final_game_situation_data

# %%
# %run Data_preparation/Data_cleaning.ipynb
